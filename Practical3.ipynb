# %%
import nltk
import os
import nltk.corpus

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
ex='Hello, How are you ? I am fine.'

# %%
tokenize=word_tokenize(ex)

# %%
tokenize
# Out:
# ['Hello', ',', 'How', 'are', 'you', '?', 'I', 'am', 'fine', '.']

# %%
stopwords=set(stopwords.words('english'))

# %%
stopwords
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
# ...

# %%
wordfilter=[w for w in tokenize if not w in stopwords]
wordfilter
# Out:
# ['Hello', ',', 'How', '?', 'I', 'fine', '.']

# %%
from nltk.stem import PorterStemmer

# %%
from nltk.tokenize import sent_tokenize,word_tokenize

# %%
import nltk
from nltk import word_tokenize
tags=nltk.pos_tag(tokenize,tagset="universal")
tags
# Out:
# [('Hello', 'NOUN'),
#  (',', '.'),
#  ('How', 'NOUN'),
#  ('are', 'VERB'),
#  ('you', 'PRON'),
#  ('?', '.'),
#  ('I', 'PRON'),
#  ('am', 'VERB'),
#  ('fine', 'ADJ'),
#  ('.', '.')]

# %%
from nltk.chunk import RegexpParser as RP

# %%
chunker = RP(r'''
chunk:
{<DT>?<JJ>*<NN>}
''')

# %%
chunker.parse([('the', 'DT'), ('book', 'NN'), (
    'has', 'VBZ'), ('many', 'JJ'), ('chapters', 'NNS')])
# Out:
# Tree('S', [Tree('chunk', [('the', 'DT'), ('book', 'NN')]), ('has', 'VBZ'), ('many', 'JJ'), ('chapters', 'NNS')])

# %%
pip install svgling
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -treamlit (c:\users\asus\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\asus\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\asus\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\asus\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\asus\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\asus\appdata\local\programs\python\python310\lib\site-packages)

# %%
chunker.parse([('the', 'DT'), ('book', 'NN'), ('many', 'JJ')])
# Out:
# Tree('S', [Tree('chunk', [('the', 'DT'), ('book', 'NN')]), ('many', 'JJ')])

# %%
chunker.parse[('Hello', 'NOUN'),
 (',', '.'),
 ('How', 'NOUN'),
 ('are', 'VERB'),
 ('you', 'PRON'),
 ('?', '.'),
 ('I', 'PRON'),
 ('am', 'VERB'),
 ('fine', 'ADJ'),
 ('.', '.')]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 chunker.parse[('Hello', 'NOUN'),
#       2  (',', '.'),
#       3  ('How', 'NOUN'),
#       4  ('are', 'VERB'),
#       5  ('you', 'PRON'),
#       6  ('?', '.'),
#       7  ('I', 'PRON'),
#       8  ('am', 'VERB'),
#       9  ('fine', 'ADJ'),
#      10  ('.', '.')]
#
# TypeError: 'method' object is not subscriptable

# %%
chunker.parse([('Hello', 'NOUN'),
 (',', '.'),
 ('How', 'NOUN'),
 ('are', 'VERB'),
 ('you', 'PRON'),
 ('?', '.'),
 ('I', 'PRON'),
 ('am', 'VERB'),
 ('fine', 'ADJ'),
 ('.', '.')])
# Out:
# Tree('S', [('Hello', 'NOUN'), (',', '.'), ('How', 'NOUN'), ('are', 'VERB'), ('you', 'PRON'), ('?', '.'), ('I', 'PRON'), ('am', 'VERB'), ('fine', 'ADJ'), ('.', '.')])

# %%
from nltk.corpus import state_union

# %%
state_union.fileids()
# Out:
# ['1945-Truman.txt',
#  '1946-Truman.txt',
#  '1947-Truman.txt',
#  '1948-Truman.txt',
#  '1949-Truman.txt',
#  '1950-Truman.txt',
#  '1951-Truman.txt',
#  '1953-Eisenhower.txt',
#  '1954-Eisenhower.txt',
#  '1955-Eisenhower.txt',
#  '1956-Eisenhower.txt',
#  '1957-Eisenhower.txt',
#  '1958-Eisenhower.txt',
#  '1959-Eisenhower.txt',
#  '1960-Eisenhower.txt',
#  '1961-Kennedy.txt',
#  '1962-Kennedy.txt',
#  '1963-Johnson.txt',
#  '1963-Kennedy.txt',
#  '1964-Johnson.txt',
#  '1965-Johnson-1.txt',
#  '1965-Johnson-2.txt',
#  '1966-Johnson.txt',
#  '1967-Johnson.txt',
#  '1968-Johnson.txt',
#  '1969-Johnson.txt',
#  '1970-Nixon.txt',
#  '1971-Nixon.txt',
#  '1972-Nixon.txt',
#  '1973-Nixon.txt',
#  '1974-Nixon.txt',
#  '1975-Ford.txt',
#  '1976-Ford.txt',
#  '1977-Ford.txt',
#  '1978-Carter.txt',
#  '1979-Carter.txt',
#  '1980-Carter.txt',
#  '1981-Reagan.txt',
#  '1982-Reagan.txt',
#  '1983-Reagan.txt',
#  '1984-Reagan.txt',
#  '1985-Reagan.txt',
#  '1986-Reagan.txt',
# ...

# %%
file=nltk.corpus.state_union.words('1945-Truman.txt')

# %%
file
# Out:
# ['PRESIDENT', 'HARRY', 'S', '.', 'TRUMAN', "'", 'S', ...]

# %%
file=' '.join(file)

# %%
token=word_tokenize(file)

# %%
tags1=nltk.pos_tag(token,tagset='')

# %%
tags1
# Out:
# [('PRESIDENT', 'NNP'),
#  ('HARRY', 'NNP'),
#  ('S', 'NNP'),
#  ('.', '.'),
#  ('TRUMAN', 'NNP'),
#  ("'", 'POS'),
#  ('S', 'NNP'),
#  ('ADDRESS', 'NNP'),
#  ('BEFORE', 'IN'),
#  ('A', 'NNP'),
#  ('JOINT', 'NNP'),
#  ('SESSION', 'NNP'),
#  ('OF', 'IN'),
#  ('THE', 'NNP'),
#  ('CONGRESS', 'NNP'),
#  ('April', 'NNP'),
#  ('16', 'CD'),
#  (',', ','),
#  ('1945', 'CD'),
#  ('Mr', 'NNP'),
#  ('.', '.'),
#  ('Speaker', 'NNP'),
#  (',', ','),
#  ('Mr', 'NNP'),
#  ('.', '.'),
#  ('President', 'NNP'),
#  (',', ','),
#  ('Members', 'NNP'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Congress', 'NNP'),
#  (':', ':'),
#  ('It', 'PRP'),
#  ('is', 'VBZ'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('heavy', 'JJ'),
#  ('heart', 'NN'),
#  ('that', 'IN'),
#  ('I', 'PRP'),
#  ('stand', 'VBP'),
#  ('before', 'IN'),
#  ('you', 'PRP'),
#  (',', ','),
#  ('my', 'PRP$'),
#  ('friends', 'NNS'),
#  ('and', 'CC'),
#  ('colleagues', 'NNS'),
#  (',', ','),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('Congress', 'NNP'),
# ...

# %%
chunker.parse([('PRESIDENT', 'NNP'),
 ('HARRY', 'NNP'),
 ('S', 'NNP'),
 ('.', '.'),
 ('TRUMAN', 'NNP'),
 ("'", 'POS'),
 ('S', 'NNP'),
 ('ADDRESS', 'NNP'),
 ('BEFORE', 'IN'),
 ('A', 'NNP'),
 ('JOINT', 'NNP'),
 ('SESSION', 'NNP'),
 ('OF', 'IN'),
 ('THE', 'NNP'),
 ('CONGRESS', 'NNP'),
 ('April', 'NNP'),
 ('16', 'CD'),
 (',', ','),
 ('1945', 'CD'),
 ('Mr', 'NNP'),
 ('.', '.'),
 ('Speaker', 'NNP'),
 (',', ','),
 ('Mr', 'NNP'),
 ('.', '.'),
 ('President', 'NNP'),
 (',', ','),
 ('Members', 'NNP'),
 ('of', 'IN'),
 ('the', 'DT'),
 ('Congress', 'NNP'),
 (':', ':'),
 ('It', 'PRP'),
 ('is', 'VBZ'),
 ('with', 'IN'),
 ('a', 'DT'),
 ('heavy', 'JJ'),
 ('heart', 'NN'),
 ('that', 'IN'),
 ('I', 'PRP'),
 ('stand', 'VBP'),
 ('before', 'IN'),
 ('you', 'PRP'),
 (',', ','),
 ('my', 'PRP$'),
 ('friends', 'NNS'),
 ('and', 'CC'),
 ('colleagues', 'NNS'),
 (',', ','),
 ('in', 'IN'),
 ('the', 'DT'),
 ('Congress', 'NNP'),
 ('of', 'IN'),
 ('the', 'DT'),
 ('United', 'NNP'),
 ('States', 'NNPS'),
 ('.', '.'),
 ('Only', 'RB'),
 ('yesterday', 'NN'),
 (',', ','),
 ('we', 'PRP'),
 ('laid', 'VBD'),
 ('to', 'TO'),
 ('rest', 'VB'),
 ('the', 'DT'),
 ('mortal', 'NN'),
 ('remains', 'VBZ'),
 ('of', 'IN'),
 ('our', 'PRP$'),
 ('beloved', 'JJ'),
 ('President', 'NNP'),
 (',', ','),
 ('Franklin', 'NNP'),
 ('Delano', 'NNP'),
 ('Roosevelt', 'NNP'),
 ('.', '.'),
 ('At', 'IN'),
 ('a', 'DT'),
 ('time', 'NN'),
 ('like', 'IN'),
 ('this', 'DT'),
 (',', ','),
 ('words', 'NNS'),
 ('are', 'VBP'),
 ('inadequate', 'JJ'),
 ('.', '.'),
 ('The', 'DT'),
 ('most', 'RBS'),
 ('eloquent', 'JJ'),
 ('tribute', 'NN'),
 ('would', 'MD'),
 ('be', 'VB'),
 ('a', 'DT'),
 ('reverent', 'JJ'),
 ('silence', 'NN'),
 ('.', '.'),
 ('Yet', 'CC'),
 (',', ','),
 ('in', 'IN'),
 ('this', 'DT'),
 ('decisive', 'JJ'),
 ('hour', 'NN'),
 (',', ','),
 ('when', 'WRB'),
 ('world', 'NN'),
 ('events', 'NNS'),
 ('are', 'VBP'),
 ('moving', 'VBG'),
 ('so', 'RB'),
 ('rapidly', 'RB'),
 (',', ','),
 ('our', 'PRP$'),
 ('silence', 'NN'),
 ('might', 'MD'),
 ('be', 'VB'),
 ('misunderstood', 'VBN'),
 ('and', 'CC'),
 ('might', 'MD'),
 ('give', 'VB'),
 ('comfort', 'NN'),
 ('to', 'TO'),
 ('our', 'PRP$'),
 ('enemies', 'NNS'),
 ('.', '.'),
 ('In', 'IN'),
 ('His', 'PRP$'),
 ('infinite', 'JJ'),
 ('wisdom', 'NN'),
 (',', ','),
 ('Almighty', 'NNP'),
 ('God', 'NNP'),
 ('has', 'VBZ'),
 ('seen', 'VBN'),
 ('fit', 'JJ'),
 ('to', 'TO'),
 ('take', 'VB'),
 ('from', 'IN'),
 ('us', 'PRP'),
 ('a', 'DT'),
 ('great', 'JJ'),
 ('man', 'NN'),
 ('who', 'WP'),
 ('loved', 'VBD'),
 (',', ','),
 ('and', 'CC'),
 ('was', 'VBD'),
 ('beloved', 'VBN'),
 ('by', 'IN'),
 (',', ','),
 ('all', 'DT'),
 ('humanity', 'NN'),
 ('.', '.'),
 ('No', 'DT'),
 ('man', 'NN'),
 ('could', 'MD'),
 ('possibly', 'RB'),
 ('fill', 'VB'),
 ('the', 'DT'),
 ('tremendous', 'JJ'),
 ('void', 'NN'),
 ('left', 'VBN'),
 ('by', 'IN'),
 ('the', 'DT'),
 ('passing', 'NN'),
 ('of', 'IN'),
 ('that', 'DT'),
 ('noble', 'JJ'),
 ('soul', 'NN'),
 ('.', '.'),
 ('No', 'DT'),
 ('words', 'NNS'),
 ('can', 'MD'),
 ('ease', 'VB'),
 ('the', 'DT'),
 ('aching', 'VBG'),
 ('hearts', 'NNS'),
 ('of', 'IN'),
 ('untold', 'JJ'),
 ('millions', 'NNS'),
 ('of', 'IN'),
 ('every', 'DT'),
 ('race', 'NN'),
 (',', ','),
 ('creed', 'NN'),
 ('and', 'CC'),
 ('color', 'NN'),
 ('.', '.'),
 ('The', 'DT'),
 ('world', 'NN'),
 ('knows', 'VBZ'),
 ('it', 'PRP'),
 ('has', 'VBZ'),
 ('lost', 'VBN'),
 ('a', 'DT'),
 ('heroic', 'JJ'),
 ('champion', 'NN'),
 ('of', 'IN'),
 ('justice', 'NN'),
 ('and', 'CC'),
 ('freedom', 'NN'),
 ('.', '.'),
 ('Tragic', 'NNP'),
 ('fate', 'NN'),
 ('has', 'VBZ'),
 ('thrust', 'VBN'),
 ('upon', 'IN'),
 ('us', 'PRP'),
 ('grave', 'VBP'),
 ('responsibilities', 'NNS'),
 ('.', '.'),
 ('We', 'PRP'),
 ('must', 'MD'),
 ('carry', 'VB'),
 ('on', 'IN'),
 ('.', '.'),
 ('Our', 'PRP$'),
 ('departed', 'JJ'),
 ('leader', 'NN'),
 ('never', 'RB'),
 ('looked', 'VBD'),
 ('backward', 'RB'),
 ('.', '.'),
 ('He', 'PRP'),
 ('looked', 'VBD'),
 ('forward', 'RB'),
 ('and', 'CC'),
 ('moved', 'VBD'),
 ('forward', 'RB'),
 ('.', '.'),
 ('That', 'DT'),
 ('is', 'VBZ'),
 ('what', 'WP'),
 ('he', 'PRP'),
 ('would', 'MD'),
 ('want', 'VB'),
 ('us', 'PRP'),
 ('to', 'TO'),
 ('do', 'VB'),
 ('.', '.'),
 ('That', 'DT'),
 ('is', 'VBZ'),
 ('what', 'WP'),
 ('America', 'NNP'),
 ('will', 'MD'),
 ('do', 'VB'),
 ('.', '.'),
 ('So', 'RB'),
 ('much', 'JJ'),
 ('blood', 'NN'),
 ('has', 'VBZ'),
 ('already', 'RB'),
 ('been', 'VBN'),
 ('shed', 'VBN'),
 ('for', 'IN'),
 ('the', 'DT'),
 ('ideals', 'NNS'),
 ('which', 'WDT'),
 ('we', 'PRP'),
 ('cherish', 'VBP'),
 (',', ','),
 ('and', 'CC'),
 ('for', 'IN'),
 ('which', 'WDT'),
 ('Franklin', 'NNP'),
 ('Delano', 'NNP'),
 ('Roosevelt', 'NNP'),
 ('lived', 'VBD'),
 ('and', 'CC'),
 ('died', 'VBD'),
 (',', ','),
 ('that', 'IN'),
 ('we', 'PRP'),
 ('dare', 'VBP'),
 ('not', 'RB'),
 ('permit', 'VB'),
 ('even', 'RB'),
 ('a', 'DT'),
 ('momentary', 'JJ'),
 ('pause', 'NN'),
 ('in', 'IN'),
 ('the', 'DT'),
 ('hard', 'JJ'),
 ('fight', 'NN'),
 ('for', 'IN'),
 ('victory', 'NN'),
 ('.', '.'),
 ('Today', 'NN'),
 (',', ','),
 ('the', 'DT'),
 ('entire', 'JJ'),
 ('world', 'NN'),
 ('is', 'VBZ'),
 ('looking', 'VBG'),
 ('to', 'TO'),
 ('America', 'NNP'),
 ('for', 'IN'),
 ('enlightened', 'JJ'),
 ('leadership', 'NN'),
 ('to', 'TO'),
 ('peace', 'NN'),
 ('and', 'CC'),
 ('progress', 'NN'),
 ('.', '.'),
 ('Such', 'PDT'),
 ('a', 'DT'),
 ('leadership', 'NN'),
 ('requires', 'VBZ'),
 ('vision', 'NN'),
 (',', ','),
 ('courage', 'NN'),
 ('and', 'CC'),
 ('tolerance', 'NN'),
 ('.', '.'),
 ('It', 'PRP'),
 ('can', 'MD'),
 ('be', 'VB'),
 ('provided', 'VBN'),
 ('only', 'RB'),
 ('by', 'IN'),
 ('a', 'DT'),
 ('united', 'JJ'),
 ('nation', 'NN'),
 ('deeply', 'RB'),
 ('devoted', 'VBN'),
 ('to', 'TO'),
 ('the', 'DT'),
 ('highest', 'JJS'),
 ('ideals', 'NNS'),
 ('.', '.'),
 ('With', 'IN'),
 ('great', 'JJ'),
 ('humility', 'NN'),
 ('I', 'PRP'),
 ('call', 'VBP'),
 ('upon', 'IN'),
 ('all', 'DT'),
 ('Americans', 'NNPS'),
 ('to', 'TO'),
 ('help', 'VB'),
 ('me', 'PRP'),
 ('keep', 'VB'),
 ('our', 'PRP$'),
 ('nation', 'NN'),
 ('united', 'VBN'),
 ('in', 'IN'),
 ('defense', 'NN'),
 ('of', 'IN'),
 ('those', 'DT'),
 ('ideals', 'NNS'),
 ('which', 'WDT'),
 ('have', 'VBP'),
 ('been', 'VBN'),
 ('so', 'RB'),
 ('eloquently', 'RB'),
 ('proclaimed', 'VBN'),
 ('by', 'IN'),
 ('Franklin', 'NNP'),
 ('Roosevelt', 'NNP'),
 ('.', '.'),
 ('I', 'PRP'),
 ('want', 'VBP'),
 ('in', 'IN'),
 ('turn', 'NN'),
 ('to', 'TO'),
 ('assure', 'VB'),
 ('my', 'PRP$'),
 ('fellow', 'JJ'),
 ('Americans', 'NNPS'),
 ('and', 'CC'),
 ('all', 'DT'),
 ('of', 'IN'),
 ('those', 'DT'),
 ('who', 'WP'),
 ('love', 'VBP'),
 ('peace', 'NN'),
 ('and', 'CC'),
 ('liberty', 'NN'),
 ('throughout', 'IN'),
 ('the', 'DT'),
 ('world', 'NN'),
 ('that', 'IN'),
 ('I', 'PRP'),
 ('will', 'MD'),
 ('support', 'VB'),
 ('and', 'CC'),
 ('defend', 'VB'),
 ('those', 'DT'),
 ('ideals', 'NNS'),
 ('with', 'IN'),
 ('all', 'DT'),
 ('my', 'PRP$'),
 ('strength', 'NN'),
 ('and', 'CC'),
 ('all', 'DT'),
 ('my', 'PRP$'),
 ('heart', 'NN'),
 ('.', '.'),
 ('That', 'DT'),
 ('is', 'VBZ'),
 ('my', 'PRP$'),
 ('duty', 'NN'),
 ('and', 'CC'),
 ('I', 'PRP'),
 ('shall', 'MD'),
 ('not', 'RB'),
 ('shirk', 'VB'),
 ('it', 'PRP'),
 ('.', '.'),
 ('So', 'CC'),
 ('that', 'IN'),
 ('there', 'EX'),
 ('can', 'MD'),
 ('be', 'VB'),
 ('no', 'DT'),
 ('possible', 'JJ'),
 ('misunderstanding', 'NN'),
 (',', ','),
 ('both', 'DT'),
 ('Germany', 'NNP'),
 ('and', 'CC'),
 ('Japan', 'NNP'),
 ('can', 'MD'),
 ('be', 'VB'),
 ('certain', 'JJ'),
 (',', ','),
 ('beyond', 'IN'),
 ('any', 'DT'),
 ('shadow', 'NN'),
 ('of', 'IN'),
 ('a', 'DT'),
 ('doubt', 'NN'),
 (',', ','),
 ('that', 'IN'),
 ('America', 'NNP'),
 ('will', 'MD'),
 ('continue', 'VB'),
 ('the', 'DT'),
 ('fight', 'NN'),
 ('for', 'IN'),
 ('freedom', 'NN'),
 ('until', 'IN'),
 ('no', 'DT'),
 ('vestige', 'NN'),
 ('of', 'IN'),
 ('resistance', 'NN'),
 ('remains', 'VBZ'),
 ('!', '.'),
 ('We', 'PRP'),
 ('are', 'VBP'),
 ('deeply', 'RB'),
 ('conscious', 'JJ'),
 ('of', 'IN'),
 ('the', 'DT'),
 ('fact', 'NN'),
 ('that', 'IN'),
 ('much', 'JJ'),
 ('hard', 'JJ'),
 ('fighting', 'NN'),
 ('is', 'VBZ'),
 ('still', 'RB'),
 ('ahead', 'RB'),
 ('of', 'IN'),
 ('us', 'PRP'),
 ('.', '.'),
 ('Having', 'VBG'),
 ('to', 'TO'),
 ('pay', 'VB'),
 ('such', 'PDT'),
 ('a', 'DT'),
 ('heavy', 'JJ'),
 ('price', 'NN'),
 ('to', 'TO'),
 ('make', 'VB'),
 ('complete', 'JJ'),
 ('victory', 'NN'),
 ('certain', 'JJ'),
 (',', ','),
 ('America', 'NNP'),
 ('will', 'MD'),
 ('never', 'RB'),
 ('become', 'VB'),
 ('a', 'DT'),
 ('party', 'NN'),
 ('to', 'TO'),
 ('any', 'DT'),
 ('plan', 'NN'),
 ('for', 'IN'),
 ('partial', 'JJ'),
 ('victory', 'NN'),
 ('!', '.'),
 ('To', 'TO'),
 ('settle', 'VB'),
 ('for', 'IN'),
 ('merely', 'RB'),
 ('another', 'DT'),
 ('temporary', 'JJ'),
 ('respite', 'NN'),
 ('would', 'MD'),
 ('surely', 'RB'),
 ('jeopardize', 'VB'),
 ('the', 'DT'),
 ('future', 'JJ'),
 ('security', 'NN'),
 ('of', 'IN'),
 ('all', 'PDT'),
 ('the', 'DT'),
 ('world', 'NN'),
 ('.', '.'),
 ('Our', 'PRP$'),
 ('demand', 'NN'),
 ('has', 'VBZ'),
 ('been', 'VBN'),
 (',', ','),
 ('and', 'CC'),
 ('it', 'PRP'),
 ('remains', 'VBZ'),
 ('-', ':'),
 ('Unconditional', 'JJ'),
 ('Surrender', 'NN'),
 ('!', '.'),
 ('We', 'PRP'),
 ('will', 'MD'),
 ('not', 'RB'),
 ('traffic', 'NN'),
 ('with', 'IN'),
 ('the', 'DT'),
 ('breakers', 'NNS'),
 ('of', 'IN'),
 ('the', 'DT'),
 ('peace', 'NN'),
 ('on', 'IN'),
 ('the', 'DT'),
 ('terms', 'NNS'),
 ('of', 'IN'),
 ('the', 'DT'),
 ('peace', 'NN'),
 ('.', '.'),
 ('The', 'DT'),
 ('responsibility', 'NN'),
 ('for', 'IN'),
 ('making', 'VBG'),
 ('of', 'IN'),
 ('the', 'DT'),
 ('peace', 'NN'),
 ('-', ':'),
 ('and', 'CC'),
 ('it', 'PRP'),
 ('is', 'VBZ'),
 ('a', 'DT'),
 ('very', 'RB'),
 ('grave', 'JJ'),
 ('responsibility', 'NN'),
 ('-', ':'),
 ('must', 'MD'),
 ('rest', 'VB'),
 ('with', 'IN'),
 ('the', 'DT'),
 ('defenders', 'NNS'),
 ('of', 'IN'),
 ('the', 'DT'),
 ('peace', 'NN'),
 ('.', '.'),
 ('We', 'PRP'),
 ('are', 'VBP'),
 ('not', 'RB'),
 ('unconscious', 'JJ'),
 ('of', 'IN'),
 ('the', 'DT'),
 ('dictates', 'NNS'),
 ('of', 'IN'),
 ('humanity', 'NN'),
 ('.', '.'),
 ('We', 'PRP'),
 ('do', 'VBP'),
 ('not', 'RB'),
 ('wish', 'VB'),
 ('to', 'TO'),
 ('see', 'VB'),
 ('unnecessary', 'JJ'),
 ('or', 'CC'),
 ('unjustified', 'JJ'),
 ('suffering', 'NN'),
 ('.', '.'),
 ('But', 'CC'),
 ('the', 'DT'),
 ('laws', 'NNS'),
 ('of', 'IN'),
 ('Go', 'NNP'),
 ('d', 'NN'),
 ('and', 'CC'),
 ('of', 'IN'),
 ('man', 'NN'),
 ('have', 'VBP'),
 ('been', 'VBN'),
 ('violated', 'VBN'),
 ('and', 'CC'),
 ('the', 'DT'),
 ('guilty', 'JJ'),
 ('must', 'MD'),
 ('not', 'RB'),
 ('go', 'VB'),
 ('unpunished', 'JJ'),
 ('.', '.'),
 ('Nothing', 'VBG'),
 ('shall', 'MD'),
 ('shake', 'VB'),
 ('our', 'PRP$'),
 ('determination', 'NN'),
 ('to', 'TO'),
 ('punish', 'VB'),
 ('the', 'DT'),
 ('war', 'NN'),
 ('criminals', 'NNS'),
 ('even', 'RB'),
 ('though', 'IN'),
 ('we', 'PRP'),
 ('must', 'MD'),
 ('pursue', 'VB'),
 ('them', 'PRP'),
 ('to', 'TO'),
 ('the', 'DT'),
 ('ends', 'NNS'),
 ('of', 'IN'),
 ('the', 'DT'),
 ('earth', 'NN'),
 ('.', '.'),
 ('Lasting', 'VBG'),
 ('peace', 'NN'),
 ('can', 'MD'),
 ('never', 'RB'),
 ('be', 'VB'),
 ('secured', 'VBN'),
 ('if', 'IN'),
 ('we', 'PRP'),
 ('permit', 'VBP'),
 ('our', 'PRP$'),
 ('dangerous', 'JJ'),
 ('opponents', 'NNS'),
 ('to', 'TO'),
 ('plot', 'VB'),
 ('future', 'JJ'),
 ('wars', 'NNS'),
 ('with', 'IN'),
 ('impunity', 'NN'),
 ('at', 'IN'),
 ('any', 'DT'),
 ('mountain', 'NN'),
 ('retreat', 'NN'),
 ('-', ':'),
 ('however', 'RB'),
 ('distant', 'NN'),
 ('.', '.'),
 ('In', 'IN'),
 ('this', 'DT'),
 ('shrinking', 'NN'),
 ('world', 'NN'),
 (',', ','),
 ('it', 'PRP'),
 ('is', 'VBZ'),
 ('futile', 'JJ'),
 ('to', 'TO'),
 ('seek', 'VB'),
 ('safety', 'NN'),
 ('behind', 'IN'),
 ('geographical', 'JJ'),
 ('barriers', 'NNS'),
 ('.', '.'),
 ('Real', 'JJ'),
 ('security', 'NN'),
 ('will', 'MD'),
 ('be', 'VB'),
 ('found', 'VBN'),
 ('only', 'RB'),
 ('in', 'IN'),
 ('law', 'NN'),
 ('and', 'CC'),
 ('in', 'IN'),
 ('justice', 'NN'),
 ('.', '.'),
 ('Here', 'RB'),
 ('in', 'IN'),
 ('America', 'NNP'),
 (',', ','),
 ('we', 'PRP'),
 ('have', 'VBP'),
 ('labored', 'VBN'),
 ('long', 'RB'),
 ('and', 'CC'),
 ('hard', 'RB'),
 ('to', 'TO'),
 ('achieve', 'VB'),
 ('a', 'DT'),
 ('social', 'JJ'),
 ('order', 'NN'),
 ('worthy', 'NN'),
 ('of', 'IN'),
 ('our', 'PRP$'),
 ('great', 'JJ'),
 ('heritage', 'NN'),
 ('.', '.'),
 ('In', 'IN'),
 ('our', 'PRP$'),
 ('time', 'NN'),
 (',', ','),
 ('tremendous', 'JJ'),
 ('progress', 'NN'),
 ('has', 'VBZ'),
 ('been', 'VBN'),
 ('made', 'VBN'),
 ('toward', 'IN'),
 ('a', 'DT'),
 ('really', 'RB'),
 ('democratic', 'JJ'),
 ('way', 'NN'),
 ('of', 'IN'),
 ('life', 'NN'),
 ('.', '.'),
 ('Let', 'VB'),
 ('me', 'PRP'),
 ('assure', 'VB'),
 ('the', 'DT'),
 ('forward', 'NN'),
 ('-', ':'),
 ('looking', 'VBG'),
 ('people', 'NNS'),
 ('of', 'IN'),
 ('America', 'NNP'),
 ('that', 'IN'),
 ('there', 'EX'),
 ('w', 'VB'),
 ('ill', 'NN'),
 ('be', 'VB'),
 ('no', 'DT'),
 ('relaxation', 'NN'),
 ('in', 'IN'),
 ('our', 'PRP$'),
 ('efforts', 'NNS'),
 ('to', 'TO'),
 ('improve', 'VB'),
 ('the', 'DT'),
 ('lot', 'NN'),
 ('of', 'IN'),
 ('the', 'DT'),
 ('common', 'JJ'),
 ('people', 'NNS'),
 ('.', '.'),
 ('In', 'IN'),
 ('the', 'DT'),
 ('difficult', 'JJ'),
 ('days', 'NNS'),
 ('ahead', 'RB'),
 (',', ','),
 ('unquestionably', 'RB'),
 ('we', 'PRP'),
 ('shall', 'MD'),
 ('face', 'VB'),
 ('problems', 'NNS'),
 ('of', 'IN'),
 ('staggering', 'VBG'),
 ('proportions', 'NNS'),
 ('.', '.'),
 ('However', 'RB'),
 (',', ','),
 ('with', 'IN'),
 ('the', 'DT'),
 ('faith', 'NN'),
 ('of', 'IN'),
 ('our', 'PRP$'),
 ('fathers', 'NNS'),
 ('in', 'IN'),
 ('our', 'PRP$'),
 ('hearts', 'NNS'),
 (',', ','),
 ('we', 'PRP'),
 ('do', 'VBP'),
 ('not', 'RB'),
 ('fear', 'VB'),
 ('the', 'DT'),
 ('future', 'NN'),
 ('.', '.'),
 ('On', 'IN'),
 ('the', 'DT'),
 ('battlefields', 'NNS'),
 (',', ','),
 ('we', 'PRP'),
 ('have', 'VBP'),
 ('frequently', 'RB'),
 ('faced', 'VBN'),
 ('overwhelming', 'JJ'),
 ('odds', 'NNS'),
 ('-', ':'),
 ('and', 'CC'),
 ('won', 'VBD'),
 ('!', '.'),
 ('At', 'IN'),
 ('home', 'NN'),
 (',', ','),
 ('Americans', 'NNPS'),
 ('will', 'MD'),
 ('not', 'RB'),
 ('be', 'VB'),
 ('less', 'JJR'),
 ('resolute', 'JJ'),
 ('!', '.'),
 ('We', 'PRP'),
 ('shall', 'MD'),
 ('never', 'RB'),
 ('cease', 'VB'),
 ('our', 'PRP$'),
 ('struggle', 'NN'),
 ('to', 'TO'),
 ('preserve', 'VB'),
 ('and', 'CC'),
 ('maintain', 'VB'),
 ('our', 'PRP$'),
 ('American', 'JJ'),
 ('way', 'NN'),
 ('of', 'IN'),
 ('life', 'NN'),
 ('.', '.'),
 ('At', 'IN'),
 ('this', 'DT'),
 ('moment', 'NN'),
 (',', ','),
 ('America', 'NNP'),
 (',', ','),
 ('along', 'IN'),
 ('with', 'IN'),
 ('her', 'PRP$'),
 ('brave', 'NN'),
 ('Allies', 'NNS'),
 (',', ','),
 ('is', 'VBZ'),
 ('paying', 'VBG'),
 ('again', 'RB'),
 ('a', 'DT'),
 ('heavy', 'JJ'),
 ('price', 'NN'),
 ('for', 'IN'),
 ('the', 'DT'),
 ('defense', 'NN'),
 ('of', 'IN'),
 ('our', 'PRP$'),
 ('freedom', 'NN'),
 ('.', '.'),
 ('With', 'IN'),
 ('characteristic', 'JJ'),
 ('energy', 'NN'),
 (',', ','),
 ('we', 'PRP'),
 ('are', 'VBP'),
 ('assisting', 'VBG'),
 ('in', 'IN'),
 ('the', 'DT'),
 ('liberation', 'NN'),
 ('of', 'IN'),
 ('entire', 'JJ'),
 ('nations', 'NNS'),
 ('.', '.'),
 ('Gradually', 'RB'),
 (',', ','),
 ('the', 'DT'),
 ('shackles', 'NNS'),
 ('of', 'IN'),
 ('slavery', 'NN'),
 ('are', 'VBP'),
 ('being', 'VBG'),
 ('broken', 'VBN'),
 ('by', 'IN'),
 ('t', 'NN'),
 ('he', 'PRP'),
 ('forces', 'VBZ'),
 ('of', 'IN'),
 ('freedom', 'NN'),
 ('.', '.'),
 ('All', 'DT'),
 ('of', 'IN'),
 ('us', 'PRP'),
 ('are', 'VBP'),
 ('praying', 'VBG'),
 ('for', 'IN'),
 ('a', 'DT'),
 ('speedy', 'JJ'),
 ('victory', 'NN'),
 ('.', '.'),
 ('Every', 'DT'),
 ('day', 'NN'),
 ('peace', 'NN'),
 ('is', 'VBZ'),
 ('delayed', 'VBN'),
 ('costs', 'NNS'),
 ('a', 'DT'),
 ('terrible', 'JJ'),
 ('toll', 'NN'),
 ('.', '.'),
 ('The', 'DT'),
 ('armies', 'NNS'),
 ('of', 'IN'),
 ('liberation', 'NN'),
 ('today', 'NN'),
 ('are', 'VBP'),
 ('bringing', 'VBG'),
 ('to', 'TO'),
 ('an', 'DT'),
 ('end', 'NN'),
 ('Hitler', 'NNP'),
 ("'", 'POS'),
 ('s', 'NN'),
 ('ghastly', 'RB'),
 ('threat', 'NN'),
 ('to', 'TO'),
 ('dominate', 'VB'),
 ('the', 'DT'),
 ('world', 'NN'),
 ('.', '.'),
 ('Tokyo', 'NNP'),
 ('rocks', 'NNS'),
 ('under', 'IN'),
 ('the', 'DT'),
 ('weight', 'NN'),
 ('of', 'IN'),
 ('our', 'PRP$'),
 ('bombs', 'NN'),
 ('.', '.'),
 ('The', 'DT'),
 ('grand', 'JJ'),
 ('strategy', 'NN'),
 ('of', 'IN'),
 ('the', 'DT'),
 ('United', 'NNP'),
 ('Nations', 'NNP'),
 ("'", 'POS'),
 ('war', 'NN'),
 ('has', 'VBZ'),
 ('been', 'VBN'),
 ('determined', 'VBN'),
 ('-', ':'),
 ('due', 'JJ'),
 ('in', 'IN'),
 ('no', 'DT'),
 ('small', 'JJ'),
 ('measure', 'NN'),
 ('to', 'TO'),
 ('the', 'DT'),
 ('vision', 'NN'),
 ('of', 'IN'),
 ('our', 'PRP$'),
 ('departed', 'JJ'),
 ('Commander', 'NNP'),
 ('in', 'IN'),
 ('Chief', 'NNP'),
 ('.', '.'),
 ('We', 'PRP'),
 ('are', 'VBP'),
 ('now', 'RB'),
 ('carrying', 'VBG'),
 ('out', 'RP'),
 ('our', 'PRP$'),
 ('part', 'NN'),
 ('of', 'IN'),
 ('that', 'DT'),
 ('strategy', 'NN'),
 ('under', 'IN'),
 ('the', 'DT'),
 ('able', 'JJ'),
 ('direction', 'NN'),
 ('of', 'IN'),
 ('Admiral', 'NNP'),
 ('Leahy', 'NNP'),
 (',', ','),
 ('General', 'NNP'),
 ('Marshall', 'NNP'),
 (',', ','),
 ('A', 'NNP'),
 ('dmiral', 'JJ'),
 ('King', 'NNP'),
 (',', ','),
 ('General', 'NNP'),
 ('Arnold', 'NNP'),
 (',', ','),
 ('General', 'NNP'),
 ('Eisenhower', 'NNP'),
 (',', ','),
 ('Admiral', 'NNP'),
 ('Nimitz', 'NNP'),
 ('and', 'CC'),
 ('General', 'NNP'),
 ('MacArthur', 'NNP'),
 ('.', '.'),
 ('I', 'PRP'),
 ('want', 'VBP'),
 ('the', 'DT'),
 ('entire', 'JJ'),
 ('world', 'NN'),
 ('to', 'TO'),
 ('know', 'VB'),
 ('that', 'IN'),
 ('this', 'DT'),
 ('direction', 'NN'),
 ('must', 'MD')])
# Out:
# Tree('S', [('PRESIDENT', 'NNP'), ('HARRY', 'NNP'), ('S', 'NNP'), ('.', '.'), ('TRUMAN', 'NNP'), ("'", 'POS'), ('S', 'NNP'), ('ADDRESS', 'NNP'), ('BEFORE', 'IN'), ('A', 'NNP'), ('JOINT', 'NNP'), ('SESSION', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('CONGRESS', 'NNP'), ('April', 'NNP'), ('16', 'CD'), (',', ','), ('1945', 'CD'), ('Mr', 'NNP'), ('.', '.'), ('Speaker', 'NNP'), (',', ','), ('Mr', 'NNP'), ('.', '.'), ('President', 'NNP'), (',', ','), ('Members', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('Congress', 'NNP'), (':', ':'), ('It', 'PRP'), ('is', 'VBZ'), ('with', 'IN'), Tree('chunk', [('a', 'DT'), ('heavy', 'JJ'), ('heart', 'NN')]), ('that', 'IN'), ('I', 'PRP'), ('stand', 'VBP'), ('before', 'IN'), ('you', 'PRP'), (',', ','), ('my', 'PRP$'), ('friends', 'NNS'), ('and', 'CC'), ('colleagues', 'NNS'), (',', ','), ('in', 'IN'), ('the', 'DT'), ('Congress', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('United', 'NNP'), ('States', 'NNPS'), ('.', '.'), ('Only', 'RB'), Tree('chunk', [('yesterday', 'NN')]
# ...

# %%
chunker = RP( r"""Chunk: {<.*>+}
            }<VB.?|IN|DT|TO>+{""")

# %%
chunker.parse([('PRESIDENT', 'NNP'),
 ('HARRY', 'NNP'),
 ('S', 'NNP'),
 ('.', '.'),
 ('TRUMAN', 'NNP'),
 ("'", 'POS'),
 ('S', 'NNP'),
 ('ADDRESS', 'NNP'),
 ('BEFORE', 'IN'),
 ('A', 'NNP'),
 ('JOINT', 'NNP'),
 ('SESSION', 'NNP'),
 ('OF', 'IN'),
 ('THE', 'NNP'),
 ('CONGRESS', 'NNP'),
 ('April', 'NNP'),
 ('16', 'CD'),
 (',', ','),
 ('1945', 'CD'),
 ('Mr', 'NNP'),
 ('.', '.'),
 ('Speaker', 'NNP'),
 (',', ','),
 ('Mr', 'NNP'),
 ('.', '.'),
 ('President', 'NNP'),
 (',', ','),
 ('Members', 'NNP'),
 ('of', 'IN'),
 ('the', 'DT'),
 ('Congress', 'NNP'),
 (':', ':'),
 ('It', 'PRP'),
 ('is', 'VBZ'),
 ('with', 'IN'),
 ('a', 'DT'),
 ('heavy', 'JJ'),
 ('heart', 'NN'),
 ('that', 'IN'),
 ('I', 'PRP'),
 ('stand', 'VBP'),
 ('before', 'IN'),
 ('you', 'PRP'),
 (',', ','),
 ('my', 'PRP$'),
 ('friends', 'NNS'),
 ('and', 'CC'),
 ('colleagues', 'NNS'),
 (',', ','),
 ('in', 'IN'),
 ('the', 'DT'),
 ('Congress', 'NNP'),
 ('of', 'IN'),
 ('the', 'DT'),
 ('United', 'NNP'),
 ('States', 'NNPS'),
 ('.', '.'),
 ('Only', 'RB'),
 ('yesterday', 'NN'),
 (',', ','),
 ('we', 'PRP'),
 ('laid', 'VBD'),
 ('to', 'TO'),
 ('rest', 'VB'),
 ('the', 'DT'),
 ('mortal', 'NN'),
 ('remains', 'VBZ'),
 ('of', 'IN'),
 ('our', 'PRP$'),
 ('beloved', 'JJ'),
 ('President', 'NNP'),
 (',', ','),
 ('Franklin', 'NNP'),
 ('Delano', 'NNP'),
 ('Roosevelt', 'NNP'),
 ('.', '.'),
 ('At', 'IN'),
 ('a', 'DT'),
 ('time', 'NN'),
 ('like', 'IN'),
 ('this', 'DT'),
 (',', ','),
 ('words', 'NNS'),
 ('are', 'VBP'),
 ('inadequate', 'JJ'),
 ('.', '.'),
 ('The', 'DT'),
 ('most', 'RBS'),
 ('eloquent', 'JJ'),
 ('tribute', 'NN'),
 ('would', 'MD'),
 ('be', 'VB'),
 ('a', 'DT'),
 ('reverent', 'JJ'),
 ('silence', 'NN'),
 ('.', '.'),
 ('Yet', 'CC'),
 (',', ','),
 ('in', 'IN'),
 ('this', 'DT'),
 ('decisive', 'JJ'),
 ('hour', 'NN'),
 (',', ','),
 ('when', 'WRB'),
 ('world', 'NN'),
 ('events', 'NNS'),
 ('are', 'VBP'),
 ('moving', 'VBG'),
 ('so', 'RB'),
 ('rapidly', 'RB'),
 (',', ','),
 ('our', 'PRP$'),
 ('silence', 'NN'),
 ('might', 'MD'),
 ('be', 'VB'),
 ('misunderstood', 'VBN'),
 ('and', 'CC'),
 ('might', 'MD'),
 ('give', 'VB'),
 ('comfort', 'NN'),
 ('to', 'TO'),
 ('our', 'PRP$'),
 ('enemies', 'NNS'),
 ('.', '.'),
 ('In', 'IN'),
 ('His', 'PRP$'),
 ('infinite', 'JJ'),
 ('wisdom', 'NN'),
 (',', ','),
 ('Almighty', 'NNP'),
 ('God', 'NNP'),
 ('has', 'VBZ'),
 ('seen', 'VBN'),
 ('fit', 'JJ'),
 ('to', 'TO'),
 ('take', 'VB'),
 ('from', 'IN'),
 ('us', 'PRP'),
 ('a', 'DT'),
 ('great', 'JJ'),
 ('man', 'NN'),
 ('who', 'WP'),
 ('loved', 'VBD'),
 (',', ','),
 ('and', 'CC'),
 ('was', 'VBD'),
 ('beloved', 'VBN'),
 ('by', 'IN'),
 (',', ','),
 ('all', 'DT'),
 ('humanity', 'NN'),
 ('.', '.'),
 ('No', 'DT'),
 ('man', 'NN'),
 ('could', 'MD'),
 ('possibly', 'RB'),
 ('fill', 'VB'),
 ('the', 'DT'),
 ('tremendous', 'JJ'),
 ('void', 'NN'),
 ('left', 'VBN'),
 ('by', 'IN'),
 ('the', 'DT'),
 ('passing', 'NN'),
 ('of', 'IN'),
 ('that', 'DT'),
 ('noble', 'JJ'),
 ('soul', 'NN'),
 ('.', '.'),
 ('No', 'DT'),
 ('words', 'NNS'),
 ('can', 'MD'),
 ('ease', 'VB'),
 ('the', 'DT'),
 ('aching', 'VBG'),
 ('hearts', 'NNS'),
 ('of', 'IN'),
 ('untold', 'JJ'),
 ('millions', 'NNS'),
 ('of', 'IN'),
 ('every', 'DT'),
 ('race', 'NN'),
 (',', ','),
 ('creed', 'NN'),
 ('and', 'CC'),
 ('color', 'NN'),
 ('.', '.'),
 ('The', 'DT'),
 ('world', 'NN'),
 ('knows', 'VBZ'),
 ('it', 'PRP'),
 ('has', 'VBZ'),
 ('lost', 'VBN'),
 ('a', 'DT'),
 ('heroic', 'JJ'),
 ('champion', 'NN'),
 ('of', 'IN'),
 ('justice', 'NN'),
 ('and', 'CC'),
 ('freedom', 'NN'),
 ('.', '.'),
 ('Tragic', 'NNP'),
 ('fate', 'NN'),
 ('has', 'VBZ'),
 ('thrust', 'VBN'),
 ('upon', 'IN'),
 ('us', 'PRP'),
 ('grave', 'VBP'),
 ('responsibilities', 'NNS'),
 ('.', '.'),
 ('We', 'PRP'),
 ('must', 'MD'),
 ('carry', 'VB'),
 ('on', 'IN'),
 ('.', '.'),
 ('Our', 'PRP$'),
 ('departed', 'JJ'),
 ('leader', 'NN'),
 ('never', 'RB'),
 ('looked', 'VBD'),
 ('backward', 'RB'),
 ('.', '.'),
 ('He', 'PRP'),
 ('looked', 'VBD'),
 ('forward', 'RB'),
 ('and', 'CC'),
 ('moved', 'VBD'),
 ('forward', 'RB'),
 ('.', '.'),
 ('That', 'DT'),
 ('is', 'VBZ'),
 ('what', 'WP'),
 ('he', 'PRP'),
 ('would', 'MD'),
 ('want', 'VB'),
 ('us', 'PRP'),
 ('to', 'TO'),
 ('do', 'VB'),
 ('.', '.'),
 ('That', 'DT'),
 ('is', 'VBZ'),
 ('what', 'WP'),
 ('America', 'NNP'),
 ('will', 'MD'),
 ('do', 'VB'),
 ('.', '.'),
 ('So', 'RB'),
 ('much', 'JJ'),
 ('blood', 'NN'),
 ('has', 'VBZ'),
 ('already', 'RB'),
 ('been', 'VBN'),
 ('shed', 'VBN'),
 ('for', 'IN'),
 ('the', 'DT'),
 ('ideals', 'NNS'),
 ('which', 'WDT'),
 ('we', 'PRP'),
 ('cherish', 'VBP'),
 (',', ','),
 ('and', 'CC'),
 ('for', 'IN'),
 ('which', 'WDT'),
 ('Franklin', 'NNP'),
 ('Delano', 'NNP'),
 ('Roosevelt', 'NNP'),
 ('lived', 'VBD'),
 ('and', 'CC'),
 ('died', 'VBD'),
 (',', ','),
 ('that', 'IN'),
 ('we', 'PRP'),
 ('dare', 'VBP'),
 ('not', 'RB'),
 ('permit', 'VB'),
 ('even', 'RB'),
 ('a', 'DT'),
 ('momentary', 'JJ'),
 ('pause', 'NN'),
 ('in', 'IN'),
 ('the', 'DT'),
 ('hard', 'JJ'),
 ('fight', 'NN'),
 ('for', 'IN'),
 ('victory', 'NN'),
 ('.', '.'),
 ('Today', 'NN'),
 (',', ','),
 ('the', 'DT'),
 ('entire', 'JJ'),
 ('world', 'NN'),
 ('is', 'VBZ'),
 ('looking', 'VBG'),
 ('to', 'TO'),
 ('America', 'NNP'),
 ('for', 'IN'),
 ('enlightened', 'JJ'),
 ('leadership', 'NN'),
 ('to', 'TO'),
 ('peace', 'NN'),
 ('and', 'CC'),
 ('progress', 'NN'),
 ('.', '.'),
 ('Such', 'PDT'),
 ('a', 'DT'),
 ('leadership', 'NN'),
 ('requires', 'VBZ'),
 ('vision', 'NN'),
 (',', ','),
 ('courage', 'NN'),
 ('and', 'CC'),
 ('tolerance', 'NN'),
 ('.', '.'),
 ('It', 'PRP'),
 ('can', 'MD'),
 ('be', 'VB'),
 ('provided', 'VBN'),
 ('only', 'RB'),
 ('by', 'IN'),
 ('a', 'DT'),
 ('united', 'JJ'),
 ('nation', 'NN'),
 ('deeply', 'RB'),
 ('devoted', 'VBN'),
 ('to', 'TO'),
 ('the', 'DT'),
 ('highest', 'JJS'),
 ('ideals', 'NNS'),
 ('.', '.'),
 ('With', 'IN'),
 ('great', 'JJ'),
 ('humility', 'NN'),
 ('I', 'PRP'),
 ('call', 'VBP'),
 ('upon', 'IN'),
 ('all', 'DT'),
 ('Americans', 'NNPS'),
 ('to', 'TO'),
 ('help', 'VB'),
 ('me', 'PRP'),
 ('keep', 'VB'),
 ('our', 'PRP$'),
 ('nation', 'NN'),
 ('united', 'VBN'),
 ('in', 'IN'),
 ('defense', 'NN'),
 ('of', 'IN'),
 ('those', 'DT'),
 ('ideals', 'NNS'),
 ('which', 'WDT'),
 ('have', 'VBP'),
 ('been', 'VBN'),
 ('so', 'RB'),
 ('eloquently', 'RB'),
 ('proclaimed', 'VBN'),
 ('by', 'IN'),
 ('Franklin', 'NNP'),
 ('Roosevelt', 'NNP'),
 ('.', '.'),
 ('I', 'PRP'),
 ('want', 'VBP'),
 ('in', 'IN'),
 ('turn', 'NN'),
 ('to', 'TO'),
 ('assure', 'VB'),
 ('my', 'PRP$'),
 ('fellow', 'JJ'),
 ('Americans', 'NNPS'),
 ('and', 'CC'),
 ('all', 'DT'),
 ('of', 'IN'),
 ('those', 'DT'),
 ('who', 'WP'),
 ('love', 'VBP'),
 ('peace', 'NN'),
 ('and', 'CC'),
 ('liberty', 'NN'),
 ('throughout', 'IN'),
 ('the', 'DT'),
 ('world', 'NN'),
 ('that', 'IN'),
 ('I', 'PRP'),
 ('will', 'MD'),
 ('support', 'VB'),
 ('and', 'CC'),
 ('defend', 'VB'),
 ('those', 'DT'),
 ('ideals', 'NNS'),
 ('with', 'IN'),
 ('all', 'DT'),
 ('my', 'PRP$'),
 ('strength', 'NN'),
 ('and', 'CC'),
 ('all', 'DT'),
 ('my', 'PRP$'),
 ('heart', 'NN'),
 ('.', '.'),
 ('That', 'DT'),
 ('is', 'VBZ'),
 ('my', 'PRP$'),
 ('duty', 'NN'),
 ('and', 'CC'),
 ('I', 'PRP'),
 ('shall', 'MD'),
 ('not', 'RB'),
 ('shirk', 'VB'),
 ('it', 'PRP'),
 ('.', '.'),
 ('So', 'CC'),
 ('that', 'IN'),
 ('there', 'EX'),
 ('can', 'MD'),
 ('be', 'VB'),
 ('no', 'DT'),
 ('possible', 'JJ'),
 ('misunderstanding', 'NN'),
 (',', ','),
 ('both', 'DT'),
 ('Germany', 'NNP'),
 ('and', 'CC'),
 ('Japan', 'NNP'),
 ('can', 'MD'),
 ('be', 'VB'),
 ('certain', 'JJ'),
 (',', ','),
 ('beyond', 'IN'),
 ('any', 'DT'),
 ('shadow', 'NN'),
 ('of', 'IN'),
 ('a', 'DT'),
 ('doubt', 'NN'),
 (',', ','),
 ('that', 'IN'),
 ('America', 'NNP'),
 ('will', 'MD'),
 ('continue', 'VB'),
 ('the', 'DT'),
 ('fight', 'NN'),
 ('for', 'IN'),
 ('freedom', 'NN'),
 ('until', 'IN'),
 ('no', 'DT'),
 ('vestige', 'NN'),
 ('of', 'IN'),
 ('resistance', 'NN'),
 ('remains', 'VBZ'),
 ('!', '.'),
 ('We', 'PRP'),
 ('are', 'VBP'),
 ('deeply', 'RB'),
 ('conscious', 'JJ'),
 ('of', 'IN'),
 ('the', 'DT'),
 ('fact', 'NN'),
 ('that', 'IN'),
 ('much', 'JJ'),
 ('hard', 'JJ'),
 ('fighting', 'NN'),
 ('is', 'VBZ'),
 ('still', 'RB'),
 ('ahead', 'RB'),
 ('of', 'IN'),
 ('us', 'PRP'),
 ('.', '.'),
 ('Having', 'VBG'),
 ('to', 'TO'),
 ('pay', 'VB'),
 ('such', 'PDT'),
 ('a', 'DT'),
 ('heavy', 'JJ'),
 ('price', 'NN'),
 ('to', 'TO'),
 ('make', 'VB'),
 ('complete', 'JJ'),
 ('victory', 'NN'),
 ('certain', 'JJ'),
 (',', ','),
 ('America', 'NNP'),
 ('will', 'MD'),
 ('never', 'RB'),
 ('become', 'VB'),
 ('a', 'DT'),
 ('party', 'NN'),
 ('to', 'TO'),
 ('any', 'DT'),
 ('plan', 'NN'),
 ('for', 'IN'),
 ('partial', 'JJ'),
 ('victory', 'NN'),
 ('!', '.'),
 ('To', 'TO'),
 ('settle', 'VB'),
 ('for', 'IN'),
 ('merely', 'RB'),
 ('another', 'DT'),
 ('temporary', 'JJ'),
 ('respite', 'NN'),
 ('would', 'MD'),
 ('surely', 'RB'),
 ('jeopardize', 'VB'),
 ('the', 'DT'),
 ('future', 'JJ'),
 ('security', 'NN'),
 ('of', 'IN'),
 ('all', 'PDT'),
 ('the', 'DT'),
 ('world', 'NN'),
 ('.', '.'),
 ('Our', 'PRP$'),
 ('demand', 'NN'),
 ('has', 'VBZ'),
 ('been', 'VBN'),
 (',', ','),
 ('and', 'CC'),
 ('it', 'PRP'),
 ('remains', 'VBZ'),
 ('-', ':'),
 ('Unconditional', 'JJ'),
 ('Surrender', 'NN'),
 ('!', '.'),
 ('We', 'PRP'),
 ('will', 'MD'),
 ('not', 'RB'),
 ('traffic', 'NN'),
 ('with', 'IN'),
 ('the', 'DT'),
 ('breakers', 'NNS'),
 ('of', 'IN'),
 ('the', 'DT'),
 ('peace', 'NN'),
 ('on', 'IN'),
 ('the', 'DT'),
 ('terms', 'NNS'),
 ('of', 'IN'),
 ('the', 'DT'),
 ('peace', 'NN'),
 ('.', '.'),
 ('The', 'DT'),
 ('responsibility', 'NN'),
 ('for', 'IN'),
 ('making', 'VBG'),
 ('of', 'IN'),
 ('the', 'DT'),
 ('peace', 'NN'),
 ('-', ':'),
 ('and', 'CC'),
 ('it', 'PRP'),
 ('is', 'VBZ'),
 ('a', 'DT'),
 ('very', 'RB'),
 ('grave', 'JJ'),
 ('responsibility', 'NN'),
 ('-', ':'),
 ('must', 'MD'),
 ('rest', 'VB'),
 ('with', 'IN'),
 ('the', 'DT'),
 ('defenders', 'NNS'),
 ('of', 'IN'),
 ('the', 'DT'),
 ('peace', 'NN'),
 ('.', '.'),
 ('We', 'PRP'),
 ('are', 'VBP'),
 ('not', 'RB'),
 ('unconscious', 'JJ'),
 ('of', 'IN'),
 ('the', 'DT'),
 ('dictates', 'NNS'),
 ('of', 'IN'),
 ('humanity', 'NN'),
 ('.', '.'),
 ('We', 'PRP'),
 ('do', 'VBP'),
 ('not', 'RB'),
 ('wish', 'VB'),
 ('to', 'TO'),
 ('see', 'VB'),
 ('unnecessary', 'JJ'),
 ('or', 'CC'),
 ('unjustified', 'JJ'),
 ('suffering', 'NN'),
 ('.', '.'),
 ('But', 'CC'),
 ('the', 'DT'),
 ('laws', 'NNS'),
 ('of', 'IN'),
 ('Go', 'NNP'),
 ('d', 'NN'),
 ('and', 'CC'),
 ('of', 'IN'),
 ('man', 'NN'),
 ('have', 'VBP'),
 ('been', 'VBN'),
 ('violated', 'VBN'),
 ('and', 'CC'),
 ('the', 'DT'),
 ('guilty', 'JJ'),
 ('must', 'MD'),
 ('not', 'RB'),
 ('go', 'VB'),
 ('unpunished', 'JJ'),
 ('.', '.'),
 ('Nothing', 'VBG'),
 ('shall', 'MD'),
 ('shake', 'VB'),
 ('our', 'PRP$'),
 ('determination', 'NN'),
 ('to', 'TO'),
 ('punish', 'VB'),
 ('the', 'DT'),
 ('war', 'NN'),
 ('criminals', 'NNS'),
 ('even', 'RB'),
 ('though', 'IN'),
 ('we', 'PRP'),
 ('must', 'MD'),
 ('pursue', 'VB'),
 ('them', 'PRP'),
 ('to', 'TO'),
 ('the', 'DT'),
 ('ends', 'NNS'),
 ('of', 'IN'),
 ('the', 'DT'),
 ('earth', 'NN'),
 ('.', '.'),
 ('Lasting', 'VBG'),
 ('peace', 'NN'),
 ('can', 'MD'),
 ('never', 'RB'),
 ('be', 'VB'),
 ('secured', 'VBN'),
 ('if', 'IN'),
 ('we', 'PRP'),
 ('permit', 'VBP'),
 ('our', 'PRP$'),
 ('dangerous', 'JJ'),
 ('opponents', 'NNS'),
 ('to', 'TO'),
 ('plot', 'VB'),
 ('future', 'JJ'),
 ('wars', 'NNS'),
 ('with', 'IN'),
 ('impunity', 'NN'),
 ('at', 'IN'),
 ('any', 'DT'),
 ('mountain', 'NN'),
 ('retreat', 'NN'),
 ('-', ':'),
 ('however', 'RB'),
 ('distant', 'NN'),
 ('.', '.'),
 ('In', 'IN'),
 ('this', 'DT'),
 ('shrinking', 'NN'),
 ('world', 'NN'),
 (',', ','),
 ('it', 'PRP'),
 ('is', 'VBZ'),
 ('futile', 'JJ'),
 ('to', 'TO'),
 ('seek', 'VB'),
 ('safety', 'NN'),
 ('behind', 'IN'),
 ('geographical', 'JJ'),
 ('barriers', 'NNS'),
 ('.', '.'),
 ('Real', 'JJ'),
 ('security', 'NN'),
 ('will', 'MD'),
 ('be', 'VB'),
 ('found', 'VBN'),
 ('only', 'RB'),
 ('in', 'IN'),
 ('law', 'NN'),
 ('and', 'CC'),
 ('in', 'IN'),
 ('justice', 'NN'),
 ('.', '.'),
 ('Here', 'RB'),
 ('in', 'IN'),
 ('America', 'NNP'),
 (',', ','),
 ('we', 'PRP'),
 ('have', 'VBP'),
 ('labored', 'VBN'),
 ('long', 'RB'),
 ('and', 'CC'),
 ('hard', 'RB'),
 ('to', 'TO'),
 ('achieve', 'VB'),
 ('a', 'DT'),
 ('social', 'JJ'),
 ('order', 'NN'),
 ('worthy', 'NN'),
 ('of', 'IN'),
 ('our', 'PRP$'),
 ('great', 'JJ'),
 ('heritage', 'NN'),
 ('.', '.'),
 ('In', 'IN'),
 ('our', 'PRP$'),
 ('time', 'NN'),
 (',', ','),
 ('tremendous', 'JJ'),
 ('progress', 'NN'),
 ('has', 'VBZ'),
 ('been', 'VBN'),
 ('made', 'VBN'),
 ('toward', 'IN'),
 ('a', 'DT'),
 ('really', 'RB'),
 ('democratic', 'JJ'),
 ('way', 'NN'),
 ('of', 'IN'),
 ('life', 'NN'),
 ('.', '.'),
 ('Let', 'VB'),
 ('me', 'PRP'),
 ('assure', 'VB'),
 ('the', 'DT'),
 ('forward', 'NN'),
 ('-', ':'),
 ('looking', 'VBG'),
 ('people', 'NNS'),
 ('of', 'IN'),
 ('America', 'NNP'),
 ('that', 'IN'),
 ('there', 'EX'),
 ('w', 'VB'),
 ('ill', 'NN'),
 ('be', 'VB'),
 ('no', 'DT'),
 ('relaxation', 'NN'),
 ('in', 'IN'),
 ('our', 'PRP$'),
 ('efforts', 'NNS'),
 ('to', 'TO'),
 ('improve', 'VB'),
 ('the', 'DT'),
 ('lot', 'NN'),
 ('of', 'IN'),
 ('the', 'DT'),
 ('common', 'JJ'),
 ('people', 'NNS'),
 ('.', '.'),
 ('In', 'IN'),
 ('the', 'DT'),
 ('difficult', 'JJ'),
 ('days', 'NNS'),
 ('ahead', 'RB'),
 (',', ','),
 ('unquestionably', 'RB'),
 ('we', 'PRP'),
 ('shall', 'MD'),
 ('face', 'VB'),
 ('problems', 'NNS'),
 ('of', 'IN'),
 ('staggering', 'VBG'),
 ('proportions', 'NNS'),
 ('.', '.'),
 ('However', 'RB'),
 (',', ','),
 ('with', 'IN'),
 ('the', 'DT'),
 ('faith', 'NN'),
 ('of', 'IN'),
 ('our', 'PRP$'),
 ('fathers', 'NNS'),
 ('in', 'IN'),
 ('our', 'PRP$'),
 ('hearts', 'NNS'),
 (',', ','),
 ('we', 'PRP'),
 ('do', 'VBP'),
 ('not', 'RB'),
 ('fear', 'VB'),
 ('the', 'DT'),
 ('future', 'NN'),
 ('.', '.'),
 ('On', 'IN'),
 ('the', 'DT'),
 ('battlefields', 'NNS'),
 (',', ','),
 ('we', 'PRP'),
 ('have', 'VBP'),
 ('frequently', 'RB'),
 ('faced', 'VBN'),
 ('overwhelming', 'JJ'),
 ('odds', 'NNS'),
 ('-', ':'),
 ('and', 'CC'),
 ('won', 'VBD'),
 ('!', '.'),
 ('At', 'IN'),
 ('home', 'NN'),
 (',', ','),
 ('Americans', 'NNPS'),
 ('will', 'MD'),
 ('not', 'RB'),
 ('be', 'VB'),
 ('less', 'JJR'),
 ('resolute', 'JJ'),
 ('!', '.'),
 ('We', 'PRP'),
 ('shall', 'MD'),
 ('never', 'RB'),
 ('cease', 'VB'),
 ('our', 'PRP$'),
 ('struggle', 'NN'),
 ('to', 'TO'),
 ('preserve', 'VB'),
 ('and', 'CC'),
 ('maintain', 'VB'),
 ('our', 'PRP$'),
 ('American', 'JJ'),
 ('way', 'NN'),
 ('of', 'IN'),
 ('life', 'NN'),
 ('.', '.'),
 ('At', 'IN'),
 ('this', 'DT'),
 ('moment', 'NN'),
 (',', ','),
 ('America', 'NNP'),
 (',', ','),
 ('along', 'IN'),
 ('with', 'IN'),
 ('her', 'PRP$'),
 ('brave', 'NN'),
 ('Allies', 'NNS'),
 (',', ','),
 ('is', 'VBZ'),
 ('paying', 'VBG'),
 ('again', 'RB'),
 ('a', 'DT'),
 ('heavy', 'JJ'),
 ('price', 'NN'),
 ('for', 'IN'),
 ('the', 'DT'),
 ('defense', 'NN'),
 ('of', 'IN'),
 ('our', 'PRP$'),
 ('freedom', 'NN'),
 ('.', '.'),
 ('With', 'IN'),
 ('characteristic', 'JJ'),
 ('energy', 'NN'),
 (',', ','),
 ('we', 'PRP'),
 ('are', 'VBP'),
 ('assisting', 'VBG'),
 ('in', 'IN'),
 ('the', 'DT'),
 ('liberation', 'NN'),
 ('of', 'IN'),
 ('entire', 'JJ'),
 ('nations', 'NNS'),
 ('.', '.'),
 ('Gradually', 'RB'),
 (',', ','),
 ('the', 'DT'),
 ('shackles', 'NNS'),
 ('of', 'IN'),
 ('slavery', 'NN'),
 ('are', 'VBP'),
 ('being', 'VBG'),
 ('broken', 'VBN'),
 ('by', 'IN'),
 ('t', 'NN'),
 ('he', 'PRP'),
 ('forces', 'VBZ'),
 ('of', 'IN'),
 ('freedom', 'NN'),
 ('.', '.'),
 ('All', 'DT'),
 ('of', 'IN'),
 ('us', 'PRP'),
 ('are', 'VBP'),
 ('praying', 'VBG'),
 ('for', 'IN'),
 ('a', 'DT'),
 ('speedy', 'JJ'),
 ('victory', 'NN'),
 ('.', '.'),
 ('Every', 'DT'),
 ('day', 'NN'),
 ('peace', 'NN'),
 ('is', 'VBZ'),
 ('delayed', 'VBN'),
 ('costs', 'NNS'),
 ('a', 'DT'),
 ('terrible', 'JJ'),
 ('toll', 'NN'),
 ('.', '.'),
 ('The', 'DT'),
 ('armies', 'NNS'),
 ('of', 'IN'),
 ('liberation', 'NN'),
 ('today', 'NN'),
 ('are', 'VBP'),
 ('bringing', 'VBG'),
 ('to', 'TO'),
 ('an', 'DT'),
 ('end', 'NN'),
 ('Hitler', 'NNP'),
 ("'", 'POS'),
 ('s', 'NN'),
 ('ghastly', 'RB'),
 ('threat', 'NN'),
 ('to', 'TO'),
 ('dominate', 'VB'),
 ('the', 'DT'),
 ('world', 'NN'),
 ('.', '.'),
 ('Tokyo', 'NNP'),
 ('rocks', 'NNS'),
 ('under', 'IN'),
 ('the', 'DT'),
 ('weight', 'NN'),
 ('of', 'IN'),
 ('our', 'PRP$'),
 ('bombs', 'NN'),
 ('.', '.'),
 ('The', 'DT'),
 ('grand', 'JJ'),
 ('strategy', 'NN'),
 ('of', 'IN'),
 ('the', 'DT'),
 ('United', 'NNP'),
 ('Nations', 'NNP'),
 ("'", 'POS'),
 ('war', 'NN'),
 ('has', 'VBZ'),
 ('been', 'VBN'),
 ('determined', 'VBN'),
 ('-', ':'),
 ('due', 'JJ'),
 ('in', 'IN'),
 ('no', 'DT'),
 ('small', 'JJ'),
 ('measure', 'NN'),
 ('to', 'TO'),
 ('the', 'DT'),
 ('vision', 'NN'),
 ('of', 'IN'),
 ('our', 'PRP$'),
 ('departed', 'JJ'),
 ('Commander', 'NNP'),
 ('in', 'IN'),
 ('Chief', 'NNP'),
 ('.', '.'),
 ('We', 'PRP'),
 ('are', 'VBP'),
 ('now', 'RB'),
 ('carrying', 'VBG'),
 ('out', 'RP'),
 ('our', 'PRP$'),
 ('part', 'NN'),
 ('of', 'IN'),
 ('that', 'DT'),
 ('strategy', 'NN'),
 ('under', 'IN'),
 ('the', 'DT'),
 ('able', 'JJ'),
 ('direction', 'NN'),
 ('of', 'IN'),
 ('Admiral', 'NNP'),
 ('Leahy', 'NNP'),
 (',', ','),
 ('General', 'NNP'),
 ('Marshall', 'NNP'),
 (',', ','),
 ('A', 'NNP'),
 ('dmiral', 'JJ'),
 ('King', 'NNP'),
 (',', ','),
 ('General', 'NNP'),
 ('Arnold', 'NNP'),
 (',', ','),
 ('General', 'NNP'),
 ('Eisenhower', 'NNP'),
 (',', ','),
 ('Admiral', 'NNP'),
 ('Nimitz', 'NNP'),
 ('and', 'CC'),
 ('General', 'NNP'),
 ('MacArthur', 'NNP'),
 ('.', '.'),
 ('I', 'PRP'),
 ('want', 'VBP'),
 ('the', 'DT'),
 ('entire', 'JJ'),
 ('world', 'NN'),
 ('to', 'TO'),
 ('know', 'VB'),
 ('that', 'IN'),
 ('this', 'DT'),
 ('direction', 'NN'),
 ('must', 'MD')])
# Out:
# Tree('S', [Tree('Chunk', [('PRESIDENT', 'NNP'), ('HARRY', 'NNP'), ('S', 'NNP'), ('.', '.'), ('TRUMAN', 'NNP'), ("'", 'POS'), ('S', 'NNP'), ('ADDRESS', 'NNP')]), ('BEFORE', 'IN'), Tree('Chunk', [('A', 'NNP'), ('JOINT', 'NNP'), ('SESSION', 'NNP')]), ('OF', 'IN'), Tree('Chunk', [('THE', 'NNP'), ('CONGRESS', 'NNP'), ('April', 'NNP'), ('16', 'CD'), (',', ','), ('1945', 'CD'), ('Mr', 'NNP'), ('.', '.'), ('Speaker', 'NNP'), (',', ','), ('Mr', 'NNP'), ('.', '.'), ('President', 'NNP'), (',', ','), ('Members', 'NNP')]), ('of', 'IN'), ('the', 'DT'), Tree('Chunk', [('Congress', 'NNP'), (':', ':'), ('It', 'PRP')]), ('is', 'VBZ'), ('with', 'IN'), ('a', 'DT'), Tree('Chunk', [('heavy', 'JJ'), ('heart', 'NN')]), ('that', 'IN'), Tree('Chunk', [('I', 'PRP')]), ('stand', 'VBP'), ('before', 'IN'), Tree('Chunk', [('you', 'PRP'), (',', ','), ('my', 'PRP$'), ('friends', 'NNS'), ('and', 'CC'), ('colleagues', 'NNS'), (',', ',')]), ('in', 'IN'), ('the', 'DT'), Tree('Chunk', [('Congress', 'NNP')]), ('of', 'IN')
# ...

# %%
chunker.parse([('Hello', 'NOUN'),
 (',', '.'),
 ('How', 'NOUN'),
 ('are', 'VERB'),
 ('you', 'PRON'),
 ('?', '.'),
 ('I', 'PRON'),
 ('am', 'VERB'),
 ('fine', 'ADJ'),
 ('.', '.')])
# Out:
# Tree('S', [Tree('Chunk', [('Hello', 'NOUN'), (',', '.'), ('How', 'NOUN'), ('are', 'VERB'), ('you', 'PRON'), ('?', '.'), ('I', 'PRON'), ('am', 'VERB'), ('fine', 'ADJ'), ('.', '.')])])

# %%
ex="the sun is bright"

# %%
token3=word_tokenize(ex)

# %%
token3
# Out:
# ['the', 'sun', 'is', 'bright']

# %%
postag=nltk.pos_tag(token3,tagset='')

# %%
postag
# Out:
# [('the', 'DT'), ('sun', 'NN'), ('is', 'VBZ'), ('bright', 'JJ')]

# %%
chunker.parse([('the', 'DT'), ('sun', 'NN'), ('is', 'VBZ'), ('bright', 'JJ')])
# Out:
# Tree('S', [('the', 'DT'), Tree('Chunk', [('sun', 'NN')]), ('is', 'VBZ'), Tree('Chunk', [('bright', 'JJ')])])

# %%
chunkerchunking = RP(r'''
chunk:
{<JJ>*<NN>}
''')

# %%
chunkerchunking.parse([('the', 'DT'), ('sun', 'NN'), ('is', 'VBZ'), ('bright', 'JJ')])
# Out:
# Tree('S', [('the', 'DT'), Tree('chunk', [('sun', 'NN')]), ('is', 'VBZ'), ('bright', 'JJ')])
